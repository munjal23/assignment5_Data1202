# %%
# Import pandas
import pandas as pd
import numpy as np

# %%
# Set file path to a variable
path = r"C:\Users\munjal\Documents\Data1202\youtube_dataset.csv"

# %%
# Read Data into a DataFrame
data = pd.read_csv('./youtube_dataset.csv',encoding="unicode_escape")
data.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3944 entries, 0 to 3943
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web-scraper-order      3944 non-null   object
#  1   web-scraper-start-url  3944 non-null   object
#  2   userID                 3944 non-null   object
#  3   userID-href            3944 non-null   object
#  4   name                   3944 non-null   object
#  5   uploads                3944 non-null   int64
#  6   subscribers            3944 non-null   int64
#  7   videoviews             3944 non-null   int64
#  8   country                3650 non-null   object
#  9   channeltype            3681 non-null   object
#  10  usercreated            3944 non-null   object
#  11  grade                  3944 non-null   object
#  12  YouTube_Link           59 non-null     object
#  13  YouTube_Link-href      3885 non-null   object
# ...

# %%
data.nunique()
# Out:
# web-scraper-order        3944
# web-scraper-start-url       1
# userID                   3900
# userID-href              3944
# name                     3899
# uploads                  1718
# subscribers              3940
# videoviews               3871
# country                    83
# channeltype                16
# usercreated              2499
# grade                      12
# YouTube_Link               59
# YouTube_Link-href        3885
# TwitterHandle              52
# TwitterHandle-href       3270
# InstagramHandle            42
# InstagramHandle-href     3858
# MonthlyEarnings          2485
# YearlyEarnings           3128
# dtype: int64

# %%
#taking top 1000 records into new dataframe
number_of_rows = 1000
data1000 = data.iloc[:number_of_rows]
data1000
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1     1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2     1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3     1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4     1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ..                ...                                                ...
# 995   1553037784-3900  https://socialblade.com/youtube/top/5000/mosts...
# 996   1553037792-3901  https://socialblade.com/youtube/top/5000/mosts...
# 997   1553037768-3897  https://socialblade.com/youtube/top/5000/mosts...
# 998   1553037724-3888  https://socialblade.com/youtube/top/5000/mosts...
# 999   1553037758-3896  https://socialblade.com/youtube/top/5000/mosts...
#
#              userID                                        userID-href  \
# ...

# %%
#taking the channeltype column to calculate the distribution
data1000_channeltype = data1000['channeltype']
data1000_channeltype
# Out:
# 0      Entertainment
# 1              Music
# 2              Games
# 3               Film
# 4             Sports
#            ...
# 995           Comedy
# 996           People
# 997    Entertainment
# 998            Howto
# 999              NaN
# Name: channeltype, Length: 1000, dtype: object

# %%
data1000.value_counts()
# Out:
# Series([], dtype: int64)

# %%
data1000_channeltype.isnull().sum()
# Out:
# 38

# %%
data1000_channeltype.notnull().sum()
# Out:
# 962

# %%
different_channeltype = data1000_channeltype.dropna().unique()
different_channeltype
# Out:
# array(['Entertainment', 'Music', 'Games', 'Film', 'Sports', 'Howto',
#        'Education', 'Comedy', 'News', 'People', 'Nonprofit', 'Animals',
#        'Tech', 'Autos', 'Travel'], dtype=object)

# %%
#defining function to calculate distribution of channeltype
def calculate_distribution(*args):
    
    for x in different_channeltype:

        number_of_values = data1000_channeltype.value_counts()[x]
        print("The number of",x,"in our data is",number_of_values)

# %%
#calling the function
calculate_distribution(different_channeltype,data1000_channeltype)
# Out:
# The number of Entertainment in our data is 284
# The number of Music in our data is 240
# The number of Games in our data is 115
# The number of Film in our data is 36
# The number of Sports in our data is 17
# The number of Howto in our data is 49
# The number of Education in our data is 30
# The number of Comedy in our data is 76
# The number of News in our data is 17
# The number of People in our data is 72
# The number of Nonprofit in our data is 1
# The number of Animals in our data is 2
# The number of Tech in our data is 19
# The number of Autos in our data is 3
# The number of Travel in our data is 1

# %%
#creating new CSV of top 1000 records
new_data = data1000.to_csv(r'C:\Users\munjal\Documents\DATA1202\new_data.csv',index = False, header = True)

# %%
#reading data from new csv
new_data = pd.read_csv('new_data.csv')
new_data
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1     1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2     1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3     1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4     1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ..                ...                                                ...
# 995   1553037784-3900  https://socialblade.com/youtube/top/5000/mosts...
# 996   1553037792-3901  https://socialblade.com/youtube/top/5000/mosts...
# 997   1553037768-3897  https://socialblade.com/youtube/top/5000/mosts...
# 998   1553037724-3888  https://socialblade.com/youtube/top/5000/mosts...
# 999   1553037758-3896  https://socialblade.com/youtube/top/5000/mosts...
#
#              userID                                        userID-href  \
# ...
